# %%
import tensorflow as tf
from tensorflow import keras as ks
import keras.layers as kl
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt  
layers=kl

# %%
model=ks.models.Sequential()
model.add(kl.Conv2D(filters=32, kernel_size=(3,3),input_shape=(256,256,1), activation='relu'),padding='same')
model.add(kl.Conv2D(filters=64, kernel_size=(3,3), activation='relu',padding='same'))
model.add(kl.MaxPooling2D(pool_size=(2,2)))
layers.BatchNormalization()

model.add(kl.Conv2D(filters=128, kernel_size=(3,3), activation='relu',))
model.add(kl.Conv2D(filters=64, kernel_size=(1,1), activation='relu'))
model.add(kl.Conv2D(filters=128, kernel_size=(3,3), activation='relu'))
model.add(kl.MaxPooling2D(pool_size=(2,2)))
layers.BatchNormalization()

model.add(kl.Conv2D(filters=256, kernel_size=(3,3), activation='relu'))
model.add(kl.Conv2D(filters=128, kernel_size=(1,1), activation='relu'))
model.add(kl.Conv2D(filters=256, kernel_size=(3,3), activation='relu'))
model.add(kl.MaxPooling2D(pool_size=(2,2)))
layers.BatchNormalization()

model.add(kl.Conv2D(filters=512, kernel_size=(3,3), activation='relu'))
model.add(kl.Conv2D(filters=256, kernel_size=(1,1), activation='relu'))
model.add(kl.Conv2D(filters=512, kernel_size=(3,3), activation='relu'))
model.add(kl.Conv2D(filters=256, kernel_size=(1,1), activation='relu'))
model.add(kl.Conv2D(filters=512, kernel_size=(3,3), activation='relu'))
model.add(kl.MaxPooling2D(pool_size=(2,2)))
layers.BatchNormalization()

model.add(kl.Conv2D(filters=1024, kernel_size=(3,3), activation='relu'))
model.add(kl.Conv2D(filters=512, kernel_size=(1,1), activation='relu'))
model.add(kl.Conv2D(filters=1024, kernel_size=(3,3), activation='relu'))
model.add(kl.Conv2D(filters=512, kernel_size=(1,1), activation='relu'))
model.add(kl.Conv2D(filters=1024, kernel_size=(3,3), activation='relu'))
model.add(kl.MaxPooling2D(pool_size=(2,2)))
layers.BatchNormalization()
model.add(kl.Conv2D(filters=1000, kernel_size=(1,1), activation='relu'))
 
# model.add(kl.GlobalAveragePooling2D())
model.add(kl.Flatten())
model.add(kl.Dense(64,activation="relu"))
model.add(kl.Dense(4,activation="sigmoid"))
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_177 (Conv2D)             │ (None, 254, 254, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_178 (Conv2D)             │ (None, 252, 252, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_54 (MaxPooling2D) │ (None, 126, 126, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_179 (Conv2D)             │ (None, 124, 124, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_180 (Conv2D)             │ (None, 124, 124, 64)   │         8,256 │
# ...

# %%
lf2 = tf.keras.losses.MeanSquaredError()
lf3 = tf.keras.losses.BinaryCrossentropy()
@tf.function
def combined_loss(y_true, y_pred):
    # lf1 = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
    return lf2   + lf3(y_true, y_pred)
loss_fn = combined_loss
# loss_fn=tf.keras.losses.MeanAbsoluteError()
# loss_fn=tf.keras.losses.Huber()
opt = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)
model.compile(optimizer=opt, loss=lf2, metrics=['mse'])

# %%
# opt = tf.keras.optimizers.Adam(learning_rate=0.00005)
# opt = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)
# model.compile(optimizer=opt,loss=tf.keras.losses.BinaryFocalCrossentropy(), metrics=['mse'])
# model.compile(optimizer=opt,loss=tf.keras.losses.huber, metrics=['mse'])

# %%
# model.compile(optimizer='adam', loss=tf.keras.losses.BinaryFocalCrossentropy, metrics=['mse'])

# %%
# data=pd.read_csv("final.csv")

# %%
# data=data.drop(data.columns[0],axis=1)

# %%
train_data_image="images/"

# %%
# train_csv="annotations_img_name.csv"
# data=pd.read_csv(train_csv)
# data=data.drop(data.columns[0],axis=1)

# %%
data.head(5)
# Out:
#         0    1    2    3    4
# 0  _2.jpg  268  272  268  272
# 1  _3.jpg  253  208  253  208
# 2  _4.jpg  227  195  227  195
# 3  _5.jpg  340  307  340  307
# 4  _6.jpg  201  238  201  238

# %%
person.shape
# Out:
# (256, 256, 1)

# %%
frame=np.ones((256,256,3)).astype(np.uint8)*255
frame=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
person=np.ones((256,256,1))
for x in data.iloc[:, 0]: 
    path="images/"+x
    y=cv2.imread(path)
    y=cv2.cvtColor(y,cv2.COLOR_BGR2GRAY)
    y=cv2.resize(y,(500,500))
    y=cv2.resize(y,(256,256))
    y=np.reshape(y,(256,256,1))
    person= np.concatenate((person, y), axis=2)
person.shape    
train=person.T
train = train[1:, :]
x,y,z=train.shape
train=train.reshape(x,y,z,1)

# %%
# ans=np.array([0,0,0,0])

# %%
# for x, y, z, w in zip(data.iloc[:, 1], data.iloc[:, 2], data.iloc[:, 3], data.iloc[:, 4]):
#     arr=np.array([x,y,z,w])
#     ans=np.vstack((ans,arr))
# ans = ans[1:, :]
# ans=ans*256/500

# %%
from tensorflow.keras.callbacks import ModelCheckpoint 
checkpoint = ModelCheckpoint("best_model.keras", monitor="val_loss", save_best_only=True, mode="min")
history=model.fit(train,ans,epochs=20,validation_split=0.05,batch_size=10,steps_per_epoch=7,callbacks=[checkpoint])
# Out:
# Epoch 1/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 2/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 3/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 4/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 5/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 6/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 7/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 8/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 9/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 10/20
# ...

# %%
gf=pd.DataFrame(history.history)
plt.plot(gf)

# %%
model=ks.models.load_model("best_model.keras")
vid=cv2.VideoCapture(0)
while vid.isOpened():
    _,frame=vid.read()
    frame=cv2.flip(frame,1)
    frame=cv2.resize(frame,(500,500))
    framex=cv2.cvtColor(frame,cv2.COLOR_RGB2GRAY)
    frame_x = np.reshape(framex,(1,500,500))# Shape: (500, 500, 1)
    frame_x=frame_x/255
    print(frame_x.shape)
    [[x1,y1,x2,y2]]=model.predict(frame_x)*500
    print(x1,x2,y1,y2)
    x1=int(x1)
    y1=int(y1)
    x2=int(x2)
    y2=int(y2)
    cv2.rectangle(frame,(x1,y1),(x2,y2),(0,255,0),4,1)
    cv2.imshow("frame",frame)
    if cv2.waitKey(1) &0xff==ord(" "):
        
        break
        
cv2.destroyWindow("frame")
vid.release()
# Out:
# (1, 500, 500)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 238.70044 249.41801 255.70518 244.09038
# (1, 500, 500)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 226.11888 245.4008 246.97256 235.14854
# (1, 500, 500)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 216.07387 236.64206 237.6797 227.1647
# (1, 500, 500)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 195.2406 218.5337 220.11584 211.53416
# (1, 500, 500)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 184.65573 207.0373 206.95207 202.48026
# (1, 500, 500)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 183.33475 207.49683 207.05386 201.1402
# (1, 500, 500)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 183.95392 207.94858 206.18051 200.3317
# (1, 500, 500)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 182.90263 208.03009 206.09378 200.2977
# (1, 500, 500)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 182.11058 207.30817 205.25227 200.07245
# (1, 500, 500)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 182.79529 208.47787 206.29349 201.15202
# (1, 500, 500)
# ...
